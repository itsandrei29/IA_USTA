# %% [markdown]
# <a href="https://colab.research.google.com/github/itsandrei29/IA_USTA/blob/main/FUZZY/S1_C2_FUZZY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalando la libreria

# %%
# !pip install scikit-fuzzy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.8/920.8 kB 8.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Importando las librerias

# %%
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import numpy as np #operaciones entre vectores
import matplotlib.pyplot as plt

# %% [markdown]
# # Ejercicio 1: Graficar variable temperatura

# %%
Temp = ctrl.Antecedent(np.arange(80,110,1),'Temperatura')
Temp['High'] = fuzz.trapmf(Temp.universe,[80,80,90,100])
Temp['Very High'] = fuzz.trapmf(Temp.universe,[90,100,110,110])
Temp.view()

# %% [markdown]
# # Ejercicio 2: Tres funciones de pertenercia

# %%
Temp = ctrl.Antecedent(np.arange(60,110,1),'Temperatura')
Temp['Medium'] = fuzz.trapmf(Temp.universe,[60,60,70,80])
Temp['High'] = fuzz.trapmf(Temp.universe,[70,80,90,100])
Temp['Very High'] = fuzz.trapmf(Temp.universe,[90,100,110,110])
Temp.view()
